# %% [markdown]
# # A Notebook to Learn to Run Functions

# %% [markdown]
# YIBO: The directory for this file is Assignment2_CaesarCpher and it should be Assignment2_CaesarCypher

# %% [markdown]
# This notebook will teach you to run individual functions to process data, and to use functions together into more complex compositions of functions.

# %% [markdown]
# ## Running Functions in a Notebook##

# %% [markdown]
# The following cell contains a predefined function to take text and insert line breaks after each period, exclamation point, or question mark.
#
# You have to run the cell in order for this function to be activated into your notebook.

# %%
def linebreak(text):
    string=""
    for ch in text:
        string+=ch
        if ch == "." or ch == "!" or ch == "?":
            string+="\n"
    return string

# %% [markdown]
# This function is executed when you run this cell:

# %%
inputtext=raw_input('Please Enter the Text You Want to Encipher: ')
textLineBreak=linebreak(inputtext)

print "======Text with Line Breaks========="
print textLineBreak
# Out:
# Please Enter the Text You Want to Encipher: Hello. This. Works.
# ======Text with Line Breaks=========
# Hello.
#  This.
#  Works.

# %% [markdown]
# ## About Functions ##

# %% [markdown]
# The following cell contains a predefined function to take text and generate cyphered text.
#
# ** Please make sure you have run this cell before you run other cells in this notebook. **

# %%
def cipher(text,key):
    import string
    stri=""
    for ch in text:
        if ch not in string.ascii_letters:
            stri+=ch
        else:
            output = chr(ord(ch) + key)
            outputNum = ord(output)
            if 64 < outputNum < 91 or 96 <outputNum < 123:
                        stri+=output
            else:
                x=chr(outputNum-26)
                stri+=x
    return stri

# %% [markdown]
# This is a good opportunity to mention a few programming concepts which will help us understand how data is generated by coding cells:
#
# * A **value** is one of the basic units of data, like a number or string, that a program manipulates.  In the cipher function above, "91" and "96" are values.
# * A **variable** is a name that refers to a value.  In the cipher function above, "outputNum" is a variable.
# * A **function** is a named sequence of statements that performs a computation. For example, "cipher" is a function.
# * An **argument** is a value or variable that is passed as input to a function. For example, "text" is an argument of the function cipher.

# %% [markdown]
# ## Composing Functions in a Notebook ##

# %% [markdown]
# Now we are going to take the text with line breaks that we generated above, and encypher it.
#
# In the cell below, the variable "key" stores the shift key you want to use.  The cell will also use the variable "textLineBreak" which stored the text with line break that was generated when we run the cell that run the function linebreak above.
# Both of these variables are the arguments of the function "cipher" below.
#
# When you run the cell below, you will get an encrypted text with the shift key you provide.

# %%
key = int(raw_input('Please Enter Shift Key: '))
textCiphered=cipher(textLineBreak,key)
print textCiphered
# Out:
# Please Enter Shift Key: 0
# Hello.
#  This.
#  Works.

# %% [markdown]
# The functions and variables above are only defined for this notebook and are not available in other notebooks.

# %% [markdown]
# Now you can print this notebook and turn it in.
