# %% [markdown]
# # A Notebook to Learn to Run Functions
# A function is a program that takes data as input and generates some new output. This notebook will teach you to run functions to process data, and to use functions together into more complex compositions of functions.

# %% [markdown]
# ## Running Functions in a Notebook##

# %% [markdown]
# The following cell contains a function that takes a text file and inserts line breaks after each period, exclamation point, or question mark.
#
# You have to run the cell in order for this function to be activated into your notebook.
#
# We provide three sample text files in the Caesar_Cypher folder. You can copy and paste the content when you are prompted to input text in the following cells.

# %%
def linebreak(text):
    string=""
    for ch in text:
        string+=ch
        if ch == "." or ch == "!" or ch == "?":
            string+="\n"
    return string

# %% [markdown]
# This function is executed when you run the cell below:

# %%
inputtext=input('Please Enter the Text You Want to Use in the Function: ')
textLineBreak=linebreak(inputtext)

print("======Text with Line Breaks=========")
print(textLineBreak)

# %% [markdown]
# To rerun the cell with new values, you can either select and rerun the cell above, which will override the output from the last run, or click "Edit" in the ribbon above, copy and paste a new cell and run it.

# %% [markdown]
# ## About Functions ##

# %% [markdown]
# The following cell contains a function to take text and generate cyphered text as a Caesar cypher, where each letter is replaced by another one. The new letter is found by shifting the original by a number (key) in the alphabet.

# %%
def cipher(text,key):
    import string
    stri=""
    for ch in text:
        if ch not in string.ascii_letters:
            stri+=ch
        else:
            output = chr(ord(ch) + key)
            outputNum = ord(output)
            if 64 < outputNum < 91 or 96 <outputNum < 123:
                        stri+=output
            else:
                x=chr(outputNum-26)
                stri+=x
    return stri

# %% [markdown]
# This is a good opportunity to mention a few programming concepts for those interested:
#
# * A **_function_** is a named sequence of statements that performs a computation. For example, "cipher" is a function.
# * An **_argument_** is a value or variable that is passed as input to a function. For example, "text" is an argument of the function cipher.
# * A **_value_** is one of the basic units of data, like a number or string, that a program manipulates.  In the cipher function above, "91" and "96" are values.
# * A **_variable_** is a name that refers to a value.  In the cipher function above, "outputNum" is a variable.

# %% [markdown]
# ## Composing Functions in a Notebook ##

# %% [markdown]
# Values that are generated by running earlier cells can be available in subsequent cells if they are stored in a variable.
#
# As an example, we are going to take the text with line breaks that we generated above, and encypher it.
#
# The cell below uses the variable "textLineBreak" which stored the text with line breaks that was generated when we run the cell above.
#
# When you run the cell below, you will get an encrypted text with the shift key you provide.

# %%
key = int(input('Please Enter Shift Key: '))
textCiphered=cipher(textLineBreak,key)
print(textCiphered)

# %% [markdown]
# The functions and variables above are only defined for this notebook and are not available in other notebooks.

# %% [markdown]
# Now you can print this notebook and turn it in.
