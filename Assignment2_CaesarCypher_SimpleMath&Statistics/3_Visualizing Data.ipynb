# %% [markdown]
# # A Notebook to Visualize Data

# %% [markdown]
# This notebook shows an example of how to customize a histogram visualization of your data. A histogram is an accurate representation of numerical data. It is an estimate of the probability distribution of a continuous variable. To construct a histogram, the first step is to set the number of bins. The bins are used to divide the entire range of values into a series of intervals and then count how many values fall into each interval.
#
# Run the cell below to load the histogram function.

# %%
def histogram(numbers,bins):
    numbers=numbers.split(',')
    try:
        numbers=list(map(float,numbers))
        import matplotlib.pyplot as plt
        plt.hist(numbers,bins)
        plt.title("Histogram")
        plt.xlabel("Value")
        plt.ylabel("Frequency")
        plt.show()
        plt.close('all')
    except:
        print('Please Input Numbers Only')

# %% [markdown]
# Now run the cell below. You will be asked to input your numbers seperating them with comma, and how many bins you would like in your histogram.
#
# Running the cell will generate a histogram for your data.

# %%
numbers = input('Please Enter the Numbers: ')
bins=int(input('Please Enter the Number of Bins: '))
histogram(numbers,bins)

# %% [markdown]
# You can run the cell above again and again with a different number of bins and get different visualizations.  If you want the notebook to keep all the runs, you will have to create new cells and copy the same code as the cell above for each run you want to keep. To create a new cell, click the "+" sign in the shortcut area and copy and paste the code that you want to rerun into it.
#
# You can experiment and try to create a new notebook that combines this notebook and the summarizing data notebook to generate summary statistics. To do this, first you need to click “File>>Make a Copy…” in your Jupyter Notebook’s interface and add new functional cells in the new notebook. To add new cells, just follow the same process mentioned above. You might need add some extra codes to make different functions work together.

# %% [markdown]
# Now you can print this notebook and turn it in.
